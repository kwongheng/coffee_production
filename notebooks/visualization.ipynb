# %%
import os
from sqlalchemy import create_engine, Column, Integer, String, Numeric
from sqlalchemy.orm import declarative_base, sessionmaker

DATABASE_URL = os.environ.get(
    "DATABASE_URL",
    "postgresql+psycopg2://neondb_owner:npg_6TwGIbFq2Zck@ep-nameless-heart-ax8g3p9f.c-4.us-east-2.aws.neon.tech/neondb?sslmode=require",
)
# --- Set up SQLAlchemy base and engine ---
Base = declarative_base()
engine = create_engine(DATABASE_URL, echo=False)  # set echo=True to see generated SQL
SessionLocal = sessionmaker(bind=engine)
def read_as_dataframe():
    """Read the employees table into a pandas DataFrame."""
    import pandas as pd
    df = pd.read_sql("SELECT * FROM employees;", engine)
    return df
if __name__ == "__main__":
    df = read_as_dataframe()
    print(df.head())
    print(df.info())
    print(df.describe())
    print(df.shape)
# Out:
#    id           name   department   salary
# 0   1  Alice Johnson  Engineering  95000.0
# 1   2      Bob Smith    Marketing  72000.0
# 2   3      Carol Lee        Sales  68000.0
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          3 non-null      int64
#  1   name        3 non-null      str
#  2   department  3 non-null      str
#  3   salary      3 non-null      float64
# dtypes: float64(1), int64(1), str(2)
# memory usage: 228.0 bytes
# None
#         id        salary
# count  3.0      3.000000
# mean   2.0  78333.333333
# std    1.0  14571.661996
# min    1.0  68000.000000
# 25%    1.5  70000.000000
# 50%    2.0  72000.000000
# 75%    2.5  83500.000000
# max    3.0  95000.000000
# (3, 4)
